# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ### Analytic Gaussian (normal) distribution

# %%
# Gaussian Distribution
N = 1001
# vector x:
x = np.linspace(-4,4,N)
#probability density function of a normal distibution
GaussianDist = stats.norm.pdf(x)

plt.plot(x,GaussianDist,'-',label='data1')
plt.legend()
plt.xlabel('Value')
plt.ylabel('PDF')
plt.title('Analytic Gaussian (normal) distribution')
# Out:
# Text(0.5, 1.0, 'Analytic Gaussian (normal) distribution')

# %%
print(sum(GaussianDist)) # it is not a probability distribution
# Out:
# 124.99221530601626

# %%
## Normally-distributed random numbers
n = 1000
Var = 1
Mean = 4
data1 = Var*np.random.randn(n)+ Mean

# plot data
plt.plot(data1, 'bo')

# %%
k = 20
plt.hist(data1,bins = k)
# plt.title('Histogram with ' +str(k)+ ' bins')
plt.title('Histogram with %s bins'%k)
# Out:
# Text(0.5, 1.0, 'Histogram with 20 bins')

# %%
print(np.mean(data1))
# Out:
# 4.064601389654661

# %%
## Uniformly-distributed random numbers
data2 = Var*np.random.rand(n) + Mean-Var/2

# plot data
fig,ax = plt.subplots(2,1,figsize=(5,6))

ax[0].plot(data2,'.',markersize=1)
ax[0].set_title('Uniform data values')

ax[1].hist(data2,25)
ax[1].set_title('Uniform data histogram')
# Out:
# Text(0.5, 1.0, 'Uniform data histogram')

# %%
## log-normal distribution

N = 1001
x = np.linspace(0,10,N)
lognormdist = stats.lognorm.pdf(x,1)

plt.plot(x,lognormdist)
plt.title('Analytic log-normal distribution')
# Out:
# Text(0.5, 1.0, 'Analytic log-normal distribution')

# %%
## binomial

# a binomial distribution is the probability of K heads in N coin tosses,
# given a probability of p heads (e.g., .5 is a fair coin).

n = 20 # number on coin tosses
p = .5 # probability of heads

x = range(n+2)
bindist = stats.binom.pmf(x,n,p) #a probability mass function is a function that gives the probability 
                                #that a discrete random variable is exactly equal to some value.

plt.bar(x,bindist)
plt.title('Binomial distribution (n=%s, p=%g)'%(n,p))
# Out:
# Text(0.5, 1.0, 'Binomial distribution (n=20, p=0.5)')
